# %%
# Function to display the to-do list
def display_todo_list():
    with open("todo.txt", "r") as file:
        lines = file.readlines()
        if not lines:
            print("To-Do list is empty.")
        else:
            print("To-Do List:")
            for i, task in enumerate(lines):
                print(f"{i + 1}. {task.strip()}")

# Function to add a task to the to-do list
def add_task(task):
    with open("todo.txt", "a") as file:
        file.write(task + "\n")
    print("Task added to the To-Do list.")

# Function to remove a task from the to-do list
def remove_task(task_number):
    with open("todo.txt", "r") as file:
        lines = file.readlines()
    
    if 1 <= task_number <= len(lines):
        removed_task = lines.pop(task_number - 1)
        with open("todo.txt", "w") as file:
            file.writelines(lines)
        print(f"Removed: {removed_task.strip()}")
    else:
        print("Invalid task number.")

# Main function
if __name__ == "__main__":
    while True:
        print("\nTo-Do List Application")
        print("1. Display To-Do List")
        print("2. Add Task")
        print("3. Remove Task")
        print("4. Quit")
        choice = input("Enter your choice: ")

        if choice == "1":
            display_todo_list()
        elif choice == "2":
            task = input("Enter the task: ")
            add_task(task)
        elif choice == "3":
            display_todo_list()
            task_number = int(input("Enter the task number to remove: "))
            remove_task(task_number)
        elif choice == "4":
            break
# Out:
# To-Do List Application
# 1. Display To-Do List
# 2. Add Task
# 3. Remove Task
# 4. Quit
# Enter your choice: 2
# Enter the task:
#   @media print {
#     .ms-editor-squiggles-container {
#       display:none !important;
#     }
#   }
#   .ms-editor-squiggles-container {
#     all: initial;
#   }solved the problem set for python basic
# Task added to the To-Do list.
#
# To-Do List Application
# 1. Display To-Do List
# 2. Add Task
# 3. Remove Task
# 4. Quit
# Enter your choice: 1
# To-Do List:
# 1. solved the problem set for python basic
#
# To-Do List Application
# 1. Display To-Do List
# 2. Add Task
# 3. Remove Task
# 4. Quit
# Enter your choice: 3
# To-Do List:
# 1. solved the problem set for python basic
# Enter the task number to remove: 1
# Removed: solved the problem set for python basic
#
# To-Do List Application
# 1. Display To-Do List
# 2. Add Task
# 3. Remove Task
# 4. Quit
# Enter your choice: 4
